# %% [markdown]
# <a href="https://colab.research.google.com/github/Mercy1515/Fundamentos-de-Datos--Grupo-5-Clase-Tarde/blob/main/primer_ejercicio_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Suma, Resta, Multiplicación y División
numero1 =  float (input("Ingresar el primer número :"))
numero2 =  float (input("Ingresar el segundo número :"))
suma= numero1 + numero2
resta= numero1 - numero2
divi= numero1 / numero2
multi= numero1 * numero2
print ("El resultado de la suma es: ", suma)
print ("El resultado de la resta es: ", resta)
print ("El resultado de la división es: ", divi)
print ("El resultado de la multiplicación es: ", multi)
# Out:
# Ingresar el primer número :50
# Ingresar el segundo número :20
# El resultado de la suma es:  70.0
# El resultado de la resta es:  30.0
# El resultado de la división es:  2.5
# El resultado de la multiplicación es:  1000.0
